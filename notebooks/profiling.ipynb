# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('../data/row.csv')


profile = ProfileReport(df, title="Data Analysis")
profile.to_file("../rapport/rapport_profiling.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
