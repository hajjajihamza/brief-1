# %% [markdown]
# # 1-Overview

# %%
import pandas as pd

df = pd.read_csv('../data/store-data.csv')

# df.head()
# df.tail()
# print(df.shape)
# df.info()
# df.describe()
df.describe(include=['O']) # ajouter les columns string
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count            10064      10064        9963            9763       10064
# unique            5009       1495        1334               4         793
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class    WB-21850
# freq                14         39          35            5822          38
#
#         Customer Name   Segment        Country           City       State  \
# count            9713     10064          10064          10064       10064
# unique            810         6              1            633          86
# top     William Brown  Consumer  United States  New York City  California
# freq               36      5163          10064            896        1967
#
#        Postal Code Region       Product ID         Category Sub-Category  \
# count         9864  10064            10064            10064        10064
# unique         705      4             1862                6           17
# ...

# %% [markdown]
# # 2-Data Quality Issues

# %%
 # 1 - Missing Values / NaNs
missing = df.isna().sum()
missing_percentage = (missing / len(df)) * 100
# df_missing = pd.DataFrame({"Missing Count": missing, "Percentage %": missing_percentage})
# df_missing[df_missing['Percentage %'] > 0]

# 2 - Duplicates
# print("Duplicated rows: ",df.duplicated().sum())

# 3 - Incorrect Data Types

# 4 -
# Out:
# Duplicated rows:  40
